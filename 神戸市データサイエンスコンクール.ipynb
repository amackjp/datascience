# %% [markdown]
# <a href="https://colab.research.google.com/github/kanaboshi/datascience/blob/main/%E7%A5%9E%E6%88%B8%E5%B8%82%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9%E3%82%B3%E3%83%B3%E3%82%AF%E3%83%BC%E3%83%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 初期設定コマンド

# %%
"""
初期設定コマンド
"""
# %matplotlib inline
# !pip install pydrive
from matplotlib.font_manager import FontProperties
import pandas as pd
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import data_table
import pydrive
import sys, os
import plotly.io as pio
plt.rcParams['font.family'] = 'IPAPGothic'
from matplotlib.ticker import ScalarFormatter
import statsmodels.api as sm
from pandas.plotting import autocorrelation_plot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
"""
日本語対応フォント導入
"""
# !apt-get -y install fonts-ipafont-gothic 
# !rm -r /root/.cache/matplotlib
#ランタイムの再起動
print("Done")
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-ipafont-mincho
# The following NEW packages will be installed:
#   fonts-ipafont-gothic fonts-ipafont-mincho
# 0 upgraded, 2 newly installed, 0 to remove and 19 not upgraded.
# Need to get 8,251 kB of archives.
# After this operation, 28.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-gothic all 00303-18ubuntu1 [3,526 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-mincho all 00303-18ubuntu1 [4,725 kB]
# Fetched 8,251 kB in 0s (20.3 MB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 155680 files and directories currently installed.)
# ...

# %%
#ドライブからファイルを読み込むためのコード
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#データファイルの読み込み　ここのURLにはてきぎ
CMDS_2020=pd.read_csv("/content/drive/Shareddrives/Submarine　DS/CSV/2020年町データ.csv",encoding="shift jis")
CMDS_2015=pd.read_csv("/content/drive/Shareddrives/Submarine　DS/CSV/2015年町データ.csv",encoding="shift jis")

# %% [markdown]
# ## 以下試行錯誤中

# %%
col=list(CMDS_2015.columns.values)
print(col)
col.pop(0)
col.pop(0)
print(col)
# Out:
# ['区名', '町コード', '男性人口', '女性人口', '未就学児人口', '小中学校人口', '高等学校人口', '大学等人口', '農業従事者数', '製造業従事者数', '卸売業従事者数', '医療従事者数', '情報通信業従事者数', '運輸業従事者数', '教育関係従事者数', '就業者数', '年金受給者数', '世帯平均年収', '世帯平均居住年数', '世帯数', '飲食店数', '製造業事業所数', '販売業店数']
# ['男性人口', '女性人口', '未就学児人口', '小中学校人口', '高等学校人口', '大学等人口', '農業従事者数', '製造業従事者数', '卸売業従事者数', '医療従事者数', '情報通信業従事者数', '運輸業従事者数', '教育関係従事者数', '就業者数', '年金受給者数', '世帯平均年収', '世帯平均居住年数', '世帯数', '飲食店数', '製造業事業所数', '販売業店数']

# %%
data_VAC_3=pd.DataFrame()
data_VAC_3["date"]=data_VAC["date"]
data_VAC_3["sum"]=data_VAC_2["sum"]
data_VAC_3.at[data_VAC_3.index[0],"All sum"]=data_VAC_3.at[data_VAC_3.index[0], 'sum']
def XXXXX(a):
  data_VAC_3.at[data_VAC_3.index[a+1],"All sum"]=data_VAC_3.at[data_VAC_3.index[a],"All sum"]+data_VAC_3.at[data_VAC_3.index[a+1],"sum"]

for i in range(len(data_VAC_3)-1):
  XXXXX(i)

# %%
CMDS_2015_sum=[0,0]
for i in col:
  print(i)
  CMDS_2015_sum.append(CMDS_2015[i].sum())
  print(CMDS_2015_sum)


print(CMDS_2015_sum)

df_01=pd.DataFrame(CMDS_2015_sum)
#df_new = CMDS_2015.append([CMDS_2015_sum], ignore_index=)


#CMDS_2015.iloc["sum"]=CMDS_2015_sum
# Out:
# 男性人口
# [0, 0, 724808]
# 女性人口
# [0, 0, 724808, 812458]
# 未就学児人口
# [0, 0, 724808, 812458, 74709]
# 小中学校人口
# [0, 0, 724808, 812458, 74709, 119400]
# 高等学校人口
# [0, 0, 724808, 812458, 74709, 119400, 42955]
# 大学等人口
# [0, 0, 724808, 812458, 74709, 119400, 42955, 68552]
# 農業従事者数
# [0, 0, 724808, 812458, 74709, 119400, 42955, 68552, 12015]
# 製造業従事者数
# [0, 0, 724808, 812458, 74709, 119400, 42955, 68552, 12015, 93336]
# 卸売業従事者数
# [0, 0, 724808, 812458, 74709, 119400, 42955, 68552, 12015, 93336, 155911]
# 医療従事者数
# [0, 0, 724808, 812458, 74709, 119400, 42955, 68552, 12015, 93336, 155911, 82173]
# 情報通信業従事者数
# [0, 0, 724808, 812458, 74709, 119400, 42955, 68552, 12015, 93336, 155911, 82173, 14492]
# 運輸業従事者数
# [0, 0, 724808, 812458, 74709, 119400, 42955, 68552, 12015, 93336, 155911, 82173, 14492, 42723]
# 教育関係従事者数
# [0, 0, 724808, 812458, 74709, 119400, 42955, 68552, 12015, 93336, 155911, 82173, 14492, 42723, 56898]
# 就業者数
# ...

# %%
df_01
# Out:
#              0
# 0            0
# 1            0
# 2       724808
# 3       812458
# 4        74709
# 5       119400
# 6        42955
# 7        68552
# 8        12015
# 9        93336
# 10      155911
# 11       82173
# 12       14492
# 13       42723
# 14       56898
# 15      626502
# 16      412849
# 17  3539132972
# 18       12322
# 19      737300
# 20       12386
# 21         997
# 22         889

# %%
#2015年データが読み込めているかの確認
CMDS_2015
# Out:
#      区名    町コード   男性人口   女性人口 未就学児人口 小中学校人口  高等学校人口 大学等人口  農業従事者数 製造業従事者数  \
# 0    A区  101001  3,515  3,573    412    619     237   358      14     391
# 1    A区  101002  1,712  2,394    236    374     139   204       9     275
# 2    A区  101003  1,458  1,430    169    248      84   149       6     199
# 3    A区  101004  5,142  5,008    517    810     314   455      20     655
# 4    A区  101005  1,421  1,738    164    245      92   143       6     209
# ..   ..     ...    ...    ...    ...    ...     ...   ...     ...     ...
# 749  I区  111118    987  1,124     99    178      72   108      60     165
# 750  I区  111121    125    138     11     22       9    12       6      23
# 751  I区  111123     88     86      8     15       5     9       3      11
# 752  I区  111125     81    129      9     18       6    11       6      17
# 753  I区  111126    297    305     25     50      18    27      14      50
#
#      ... 運輸業従事者数 教育関係従事者数   就業者数  年金受給者数     世帯平均年収 世帯平均居住年数    世帯数 飲食店数  \
# ...

# %%
#2020年のものも同様に
CMDS_2020
# Out:
#      区名    町コード   男性人口   女性人口  未就学児人口 小中学校人口  高等学校人口 大学等人口  農業従事者数 製造業従事者数  \
# 0    A区  101001  3,408  3,606     345    594     220   355       9     458
# 1    A区  101002  1,991  2,231     203    373     133   215       6     280
# 2    A区  101003  1,471  1,435     140    248      84   153      20     203
# 3    A区  101004  4,583  4,803     453    788     295   459       6     672
# 4    A区  101005  1,360  1,685     147    245      91   147      12     214
# ..   ..     ...    ...    ...     ...    ...     ...   ...     ...     ...
# 749  I区  111118  1,020  1,089      86    178      67   107       6     199
# 750  I区  111121    127    131      10     21       9    12       3      25
# 751  I区  111123     86     82       7     14       5     9       6      14
# 752  I区  111125     92    120       8     18       6    11      14      18
# 753  I区  111126    278    284      22     50      17    29       0      49
#
# ...

# %% [markdown]
# # 単体グラフ描画

# %%
"""
2015 左から順にヒストグラム描画
"""

# %% [markdown]
# #これより下から統計が始まる
